# %% [markdown]
# # 모델의 성능 검증하기

# %% [markdown]
# ## 데이터의 확인과 예측 (전체)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('sonar3.csv', header=None)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   0
# 1  0.0052  0.0044   0
# 2  0.0095  0.0078   0
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = df.iloc[:, 0:60]
y = df.iloc[:, 60]

# 모델 생성
model = Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 학습
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x, y, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5385 - loss: 0.6873
# Epoch 2/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5433 - loss: 0.6760
# Epoch 3/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5673 - loss: 0.6679
# Epoch 4/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5817 - loss: 0.6564
# Epoch 5/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6731 - loss: 0.6427
# Epoch 6/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6587 - loss: 0.6243
# Epoch 7/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7260 - loss: 0.6044
# Epoch 8/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7404 - loss: 0.5838
# Epoch 9/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7500 - loss: 0.5531
# Epoch 10/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7981 - loss: 0.5288
# Epoch 11/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7548 - loss: 0.5093
# Epoch 12/200
# ...

# %% [markdown]
# ## 데이터의 확인과 예측 (train_test_split)

# %%
from sklearn.model_selection import train_test_split

# 데이터셋 분할
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, shuffle=True)

# 모델 생성
model = Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 모델 학습
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4414 - loss: 0.7023
# Epoch 2/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5241 - loss: 0.6689
# Epoch 3/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5517 - loss: 0.6561
# Epoch 4/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6069 - loss: 0.6430
# Epoch 5/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5862 - loss: 0.6339
# Epoch 6/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6966 - loss: 0.6225
# Epoch 7/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7103 - loss: 0.6136
# Epoch 8/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7310 - loss: 0.6018
# Epoch 9/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7379 - loss: 0.5888
# Epoch 10/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7517 - loss: 0.5761
# Epoch 11/200
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7862 - loss: 0.5644
# Epoch 12/200
# ...

# %%
score_list = model.evaluate(x_test, y_test)
print(type(score_list), "[loss, accuracy] :", score_list)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7460 - loss: 0.8257
# <class 'list'> [loss, accuracy] : [0.8256639242172241, 0.7460317611694336]

# %% [markdown]
# ## Model 저장과 재사용

# %%
model.save("sonar3_model.keras")

# %%
from tensorflow.keras.models import load_model
del model
model = load_model("sonar3_model.keras")
score_list = model.evaluate(x_test, y_test)
print(type(score_list), "[loss, accuracy] :", score_list)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7460 - loss: 0.8257
# <class 'list'> [loss, accuracy] : [0.8256639242172241, 0.7460317611694336]

# %% [markdown]
# ## KFold 교차 검증

# %%
from sklearn.model_selection import KFold

accuracy_scores_list = []
kfold = KFold(n_splits=5, shuffle=True)
for train_index, test_index in kfold.split(x):
    # 데이터 분할
    x_train, x_test = x.iloc[train_index], x.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    # 모델 생성 및 학습
    model = Sequential()
    model.add(Dense(24, input_dim=60, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(x_train, y_train, epochs=200, batch_size=10, verbose=0) # verbose (0: 학습 과정 중 출력되는 로그를 생략, 1: 진행 바 표시, 2: 에포크마다 결과 출력)
    # 모델 평가
    accuracy = model.evaluate(x_test, y_test)[1]
    accuracy_scores_list.append(accuracy)

avg_accuracy = np.mean(accuracy_scores_list)
print("Average: ", accuracy_scores_list)    
print("Average accuracy: ", avg_accuracy)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8095 - loss: 0.5470
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7381 - loss: 1.7175
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8810 - loss: 0.3491
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8537 - loss: 0.3776
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8293 - loss: 0.8224
# Average:  [0.8095238208770752, 0.738095223903656, 0.8809523582458496, 0.8536585569381714, 0.8292682766914368]
# Average accuracy:  0.8222996473312378
