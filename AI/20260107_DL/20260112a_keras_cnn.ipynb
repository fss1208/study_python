# %% [markdown]
# # tensorflow가 제공하는 데이터셋 확인

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
import tensorflow.keras.datasets as ds
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, Adam

# %% [markdown]
# ## MNIST 필기 숫자 데이터셋

# %%
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)

plt.figure(figsize=(24,3))
plt.suptitle("MNIST", fontsize=30)
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(str(y_train[i]), fontsize=30)
    plt.axis('off')
plt.show()
# Out:
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)

# %% [markdown]
# ## CIFAR-10 자연영상 데이터셋

# %%
(x_train, y_train), (x_test, y_test) = ds.cifar10.load_data()
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
class_names = ['airplane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(24,3))
plt.suptitle("CIFAR-10", fontsize=30)
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(x_train[i])
    plt.xticks([])
    plt.yticks([])
    plt.title(class_names[y_train[i,0]], fontsize=30)
plt.show()
# Out:
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)

# %% [markdown]
# ## 필기 숫자 인식

# %% [markdown]
# ### 다층 퍼셉트론으로 MNIST 인식하기 (SGD Optimizer)

# %%
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()
x_train = x_train.reshape(60000, 784).astype('float32') / 255.0
x_test = x_test.reshape(10000, 784).astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
mlp_sgd = Sequential()
mlp_sgd.add(Dense(units=512, activation='tanh', input_shape=(784,)))
mlp_sgd.add(Dense(units=10, activation='softmax'))
mlp_sgd.compile(loss='MSE', optimizer=SGD(learning_rate=0.01), metrics=['accuracy'])
history_sgd = mlp_sgd.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# c:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 469/469 - 1s - 3ms/step - accuracy: 0.1500 - loss: 0.0892 - val_accuracy: 0.2191 - val_loss: 0.0863
# Epoch 2/50
# 469/469 - 1s - 2ms/step - accuracy: 0.3055 - loss: 0.0829 - val_accuracy: 0.3813 - val_loss: 0.0798
# Epoch 3/50
# 469/469 - 1s - 2ms/step - accuracy: 0.4448 - loss: 0.0763 - val_accuracy: 0.5054 - val_loss: 0.0729
# Epoch 4/50
# 469/469 - 1s - 2ms/step - accuracy: 0.5487 - loss: 0.0695 - val_accuracy: 0.5869 - val_loss: 0.0659
# Epoch 5/50
# 469/469 - 1s - 2ms/step - accuracy: 0.6108 - loss: 0.0628 - val_accuracy: 0.6473 - val_loss: 0.0592
# Epoch 6/50
# 469/469 - 1s - 2ms/step - accuracy: 0.6629 - loss: 0.0568 - val_accuracy: 0.7003 - val_loss: 0.0535
# Epoch 7/50
# 469/469 - 1s - 2ms/step - accuracy: 0.7103 - loss: 0.0518 - val_accuracy: 0.7424 - val_loss: 0.0487
# Epoch 8/50
# 469/469 - 1s - 2ms/step - accuracy: 0.7470 - loss: 0.0475 - val_accuracy: 0.7750 - val_loss: 0.0447
# Epoch 9/50
# 469/469 - 1s - 2ms/step - accuracy: 0.7743 - loss: 0.0439 - val_accuracy: 0.7953 - val_loss: 0.0414
# Epoch 10/50
# 469/469 - 1s - 2ms/step - accuracy: 0.7950 - loss: 0.0409 - val_accuracy: 0.8133 - val_loss: 0.0386
# Epoch 11/50
# 469/469 - 1s - 2ms/step - accuracy: 0.8095 - loss: 0.0384 - val_accuracy: 0.8246 - val_loss: 0.0362
# Epoch 12/50
# 469/469 - 1s - 2ms/step - accuracy: 0.
50
# 469/469 - 1s - 2ms/step - accuracy: 0.8847 - loss: 0.0195 - val_accuracy: 0.8910 - val_loss: 0.0184
# Epoch 45/50
# 469/469 - 1s - 2ms/step - accuracy: 0.8851 - loss: 0.0193 - val_accuracy: 0.8917 - val_loss: 0.0183
# Epoch 46/50
# 469/469 - 1s - 2ms/step - accuracy: 0.8858 - loss: 0.0192 - val_accuracy: 0.8922 - val_loss: 0.0182
# Epoch 47/50
# 469/469 - 1s - 2ms/step - accuracy: 0.8866 - loss: 0.0191 - val_accuracy: 0.8926 - val_loss: 0.0180
# Epoch 48/50
# 469/469 - 1s - 2ms/step - accuracy: 0.8870 - loss: 0.0189 - val_accuracy: 0.8931 - val_loss: 0.0179
# Epoch 49/50
# 469/469 - 1s - 2ms/step - accuracy: 0.8876 - loss: 0.0188 - val_accuracy: 0.8933 - val_loss: 0.0178
# Epoch 50/50
# 469/469 - 1s - 2ms/step - accuracy: 0.8880 - loss: 0.0187 - val_accuracy: 0.8941 - val_loss: 0.0177

# %%
res_sgd = mlp_sgd.evaluate(x_test, y_test, verbose=0)
print('accuracy =', res_sgd[1] * 100, '%')
# Out:
# accuracy = 89.410001039505 %

# %% [markdown]
# ### Adam Optimizer를 사용하여 성능 향상

# %%
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()
x_train = x_train.reshape(60000, 784).astype('float32') / 255.0
x_test = x_test.reshape(10000, 784).astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
mlp_adam = Sequential()
mlp_adam.add(Dense(units=512, activation='tanh', input_shape=(784,)))
mlp_adam.add(Dense(units=10, activation='softmax'))
mlp_adam.compile(loss='MSE', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])
history_adam = mlp_adam.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# 469/469 - 2s - 4ms/step - accuracy: 0.9023 - loss: 0.0147 - val_accuracy: 0.9318 - val_loss: 0.0105
# Epoch 2/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9434 - loss: 0.0088 - val_accuracy: 0.9505 - val_loss: 0.0076
# Epoch 3/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9586 - loss: 0.0065 - val_accuracy: 0.9612 - val_loss: 0.0060
# Epoch 4/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9683 - loss: 0.0051 - val_accuracy: 0.9663 - val_loss: 0.0052
# Epoch 5/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9756 - loss: 0.0041 - val_accuracy: 0.9696 - val_loss: 0.0048
# Epoch 6/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9796 - loss: 0.0034 - val_accuracy: 0.9732 - val_loss: 0.0041
# Epoch 7/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9831 - loss: 0.0028 - val_accuracy: 0.9746 - val_loss: 0.0039
# Epoch 8/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9865 - loss: 0.0023 - val_accuracy: 0.9767 - val_loss: 0.0036
# Epoch 9/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9886 - loss: 0.0020 - val_accuracy: 0.9773 - val_loss: 0.0036
# Epoch 10/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9899 - loss: 0.0017 - val_accuracy: 0.9757 - val_loss: 0.0037
# Epoch 11/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9920 - loss: 0.0015 - val_accuracy: 0.9798 - val_loss: 0.0031
# Epoch 12/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9934 - loss: 0.0012 - val_accuracy: 0.9781 - val_loss: 0.0034
# Epoch 13/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9945 - loss: 0.0011 - val_accuracy: 0.9790 - val_loss: 0.0032
# Epoch 14/50
# 469/469 - 1s - 2ms/step - accuracy: 0.9945 - loss: 9.9988e-04 - val_accuracy: 0.9809 - val_loss: 0.0029
# Epoch 15/50
# 469/469 - 1s - 2ms/step - accuracy: 0.9959 - loss: 7.8091e-04 - val_accuracy: 0.9790 - val_loss: 0.0030
# Epoch 16/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9964 - loss: 7.1135e-04 - val_accuracy: 0.9812 - val_loss: 0.0030
# Epoch 17/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9971 - loss: 6.1748e-04 - val_accuracy: 0.9810 - val_loss: 0.0030
# Epoch 18/50
# 469/469 - 1s - 3ms/step - accuracy: 0.
50
# 469/469 - 1s - 3ms/step - accuracy: 0.9990 - loss: 1.8702e-04 - val_accuracy: 0.9824 - val_loss: 0.0028
# Epoch 49/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9991 - loss: 1.6959e-04 - val_accuracy: 0.9827 - val_loss: 0.0027
# Epoch 50/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9983 - loss: 2.8797e-04 - val_accuracy: 0.9802 - val_loss: 0.0033

# %%
res_adam = mlp_adam.evaluate(x_test, y_test, verbose=0)
print('accuracy =', res_adam[1] * 100, '%')
# Out:
# accuracy = 98.01999926567078 %

# %% [markdown]
# ## 성능 시각화

# %% [markdown]
# ### SGD & Adam 성능을 그래프로 비교

# %%
plt.plot(history_sgd.history['accuracy'], 'r--')
plt.plot(history_sgd.history['val_accuracy'], 'r')
plt.plot(history_adam.history['accuracy'], 'b--')
plt.plot(history_adam.history['val_accuracy'], 'b')
plt.title('Comparison of SGD and Adam optimizers')
plt.ylim((0.7, 1.0))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['train_sgd', 'val_sgd', 'train_adam', 'val_adam'])
plt.grid()
plt.show()

# %% [markdown]
# ## 하이퍼 매개변수 다루기

# %% [markdown]
# ### 깊은 다층 퍼셉트론으로 MNIST 인식

# %%
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()
x_train = x_train.reshape(60000, 784).astype('float32') / 255.0
x_test = x_test.reshape(10000, 784).astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
mlp_adam = Sequential()
mlp_adam.add(Dense(units=1024, activation='relu', input_shape=(784,)))
mlp_adam.add(Dense(units=512, activation='relu'))
mlp_adam.add(Dense(units=512, activation='relu'))
mlp_adam.add(Dense(units=10, activation='softmax'))
mlp_adam.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])
hist = mlp_adam.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# 469/469 - 5s - 10ms/step - accuracy: 0.8945 - loss: 0.4035 - val_accuracy: 0.9484 - val_loss: 0.1739
# Epoch 2/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9583 - loss: 0.1457 - val_accuracy: 0.9596 - val_loss: 0.1376
# Epoch 3/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9711 - loss: 0.0995 - val_accuracy: 0.9692 - val_loss: 0.0974
# Epoch 4/50
# 469/469 - 5s - 11ms/step - accuracy: 0.9790 - loss: 0.0715 - val_accuracy: 0.9753 - val_loss: 0.0824
# Epoch 5/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9845 - loss: 0.0537 - val_accuracy: 0.9749 - val_loss: 0.0826
# Epoch 6/50
# 469/469 - 5s - 11ms/step - accuracy: 0.9883 - loss: 0.0411 - val_accuracy: 0.9773 - val_loss: 0.0738
# Epoch 7/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9913 - loss: 0.0312 - val_accuracy: 0.9788 - val_loss: 0.0660
# Epoch 8/50
# 469/469 - 4s - 9ms/step - accuracy: 0.9934 - loss: 0.0247 - val_accuracy: 0.9785 - val_loss: 0.0714
# Epoch 9/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9952 - loss: 0.0181 - val_accuracy: 0.9787 - val_loss: 0.0660
# Epoch 10/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9969 - loss: 0.0131 - val_accuracy: 0.9816 - val_loss: 0.0646
# Epoch 11/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9974 - loss: 0.0111 - val_accuracy: 0.9814 - val_loss: 0.0663
# Epoch 12/50
# 469/469 - 4s - 9ms/step - accuracy: 0.9983 - loss: 0.0078 - val_accuracy: 0.9788 - val_loss: 0.0783
# Epoch 13/50
# 469/469 - 4s - 9ms/step - accuracy: 0.9986 - loss: 0.0067 - val_accuracy: 0.9797 - val_loss: 0.0771
# Epoch 14/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9992 - loss: 0.0045 - val_accuracy: 0.9809 - val_loss: 0.0780
# Epoch 15/50
# 469/469 - 4s - 9ms/step - accuracy: 0.9987 - loss: 0.0055 - val_accuracy: 0.9747 - val_loss: 0.1019
# Epoch 16/50
# 469/469 - 4s - 9ms/step - accuracy: 0.9990 - loss: 0.0047 - val_accuracy: 0.9795 - val_loss: 0.0801
# Epoch 17/50
# 469/469 - 4s - 9ms/step - accuracy: 0.9996 - loss: 0.0026 - val_accuracy: 0.9822 - val_loss: 0.0720
# Epoch 18/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9979 - loss: 0.0070 - val_accuracy: 0.9797 - val_loss: 0.0787
# Epoch 19/50
# 469/469 - 4s - 9ms/step - accuracy: 0.9993 - loss: 0.0031 - val_accuracy: 0.9780 - val_loss: 0.0917
# Epoch 20/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9996 - loss: 0.0020 - val_accuracy: 0.9817 - val_loss: 0.0777
# Epoch 21/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 4.7381e-04 - val_accuracy: 0.9833 - val_loss: 0.0734
# Epoch 22/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 2.4807e-04 - val_accuracy: 0.9835 - val_loss: 0.0755
# Epoch 23/50
# 469/469 - 4s - 9ms/step - accuracy: 1.0000 - loss: 1.9285e-04 - val_accuracy: 0.9836 - val_loss: 0.0770
# Epoch 24/50
# 469/469 - 4s - 9ms/step - accuracy: 1.0000 - loss: 1.7688e-04 - val_accuracy: 0.9831 - val_loss: 0.0793
# Epoch 25/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9978 - loss: 0.0070 - val_accuracy: 0.9755 - val_loss: 0.1185
# Epoch 26/50
# 469/469 - 4s - 9ms/step - accuracy: 0.9976 - loss: 0.0076 - val_accuracy: 0.9838 - val_loss: 0.0733
# Epoch 27/50
# 469/469 - 5s - 10ms/step - accuracy: 0.9998 - loss: 0.0010 - val_accuracy: 0.9840 - val_loss: 0.0748
# Epoch 28/50
# 469/469 - 4s - 9ms/step - accuracy: 1.0000 - loss: 2.6217e-04 - val_accuracy: 0.9844 - val_loss: 0.0750
# Epoch 29/50
# 469/469 - 4s - 9ms/step - accuracy: 1.0000 - loss: 1.5388e-04 - val_accuracy: 0.9840 - val_loss: 0.0777
# Epoch 30/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 1.1645e-04 - val_accuracy: 0.9840 - val_loss: 0.0791
# Epoch 31/50
# 469/469 - 4s - 9ms/step - accuracy: 1.0000 - loss: 9.1300e-05 - val_accuracy: 0.9836 - val_loss: 0.0807
# Epoch 32/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 7.3358e-05 - val_accuracy: 0.9840 - val_loss: 0.0823
# Epoch 33/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 5.9383e-05 - val_accuracy: 0.9844 - val_loss: 0.0842
# Epoch 34/50
# 469/469 - 5s - 11ms/step - accuracy: 1.0000 - loss: 5.0741e-05 - val_accuracy: 0.9840 - val_loss: 0.0856
# Epoch 35/50
# 469/469 - 5s - 11ms/step - accuracy: 1.0000 - loss: 3.9694e-05 - val_accuracy: 0.9842 - val_loss: 0.0870
# Epoch 36/50
# 469/469 - 5s - 11ms/step - accuracy: 1.0000 - loss: 3.3046e-05 - val_accuracy: 0.9837 - val_loss: 0.0890
# Epoch 37/50
# 469/469 - 5s - 11ms/step - accuracy: 1.0000 - loss: 2.7402e-05 - val_accuracy: 0.9837 - val_loss: 0.0910
# Epoch 38/50
# 469/469 - 6s - 12ms/step - accuracy: 0.9974 - loss: 0.0096 - val_accuracy: 0.9696 - val_loss: 0.1484
# Epoch 39/50
# 469/469 - 5s - 11ms/step - accuracy: 0.9974 - loss: 0.0084 - val_accuracy: 0.9835 - val_loss: 0.0799
# Epoch 40/50
# 469/469 - 5s - 11ms/step - accuracy: 0.9999 - loss: 8.5471e-04 - val_accuracy: 0.9843 - val_loss: 0.0801
# Epoch 41/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 1.9636e-04 - val_accuracy: 0.9843 - val_loss: 0.0806
# Epoch 42/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 1.2070e-04 - val_accuracy: 0.9843 - val_loss: 0.0828
# Epoch 43/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 8.8491e-05 - val_accuracy: 0.9845 - val_loss: 0.0846
# Epoch 44/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 6.7324e-05 - val_accuracy: 0.9843 - val_loss: 0.0862
# Epoch 45/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 5.2529e-05 - val_accuracy: 0.9842 - val_loss: 0.0881
# Epoch 46/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 4.1011e-05 - val_accuracy: 0.9843 - val_loss: 0.0896
# Epoch 47/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 3.2565e-05 - val_accuracy: 0.9841 - val_loss: 0.0915
# Epoch 48/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 2.6147e-05 - val_accuracy: 0.9841 - val_loss: 0.0934
# Epoch 49/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 2.0902e-05 - val_accuracy: 0.9840 - val_loss: 0.0952
# Epoch 50/50
# 469/469 - 5s - 10ms/step - accuracy: 1.0000 - loss: 1.6791e-05 - val_accuracy: 0.9842 - val_loss: 0.0969

# %%
res_adam = mlp_adam.evaluate(x_test, y_test, verbose=0)
print('accuracy =', res_adam[1] * 100, '%')
# Out:
# accuracy = 98.51999878883362 %

# %%
mlp_adam.save('mlp_adam.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.ylim((0.7, 1.0))
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['train', 'test'])
plt.grid()
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'test'])
plt.grid()
plt.show()

# %% [markdown]
# ## 자연 영상 인식

# %% [markdown]
# ### 깊은 다층 퍼셉트론으로 CIFAR-10 인식하기

# %%
(x_train, y_train), (x_test, y_test) = ds.cifar10.load_data()
x_train = x_train.reshape(50000, 3072).astype('float32') / 255.0
x_test = x_test.reshape(10000, 3072).astype('float32') / 255.0
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
mlp_adam = Sequential()
mlp_adam.add(Dense(units=1024, activation='relu', input_shape=(3072,)))
mlp_adam.add(Dense(units=512, activation='relu'))
mlp_adam.add(Dense(units=512, activation='relu'))
mlp_adam.add(Dense(units=10, activation='softmax'))
mlp_adam.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])
hist = mlp_adam.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# c:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 391/391 - 8s - 20ms/step - accuracy: 0.3496 - loss: 1.8201 - val_accuracy: 0.3750 - val_loss: 1.7333
# Epoch 2/50
# 391/391 - 7s - 17ms/step - accuracy: 0.4212 - loss: 1.6313 - val_accuracy: 0.4486 - val_loss: 1.5632
# Epoch 3/50
# 391/391 - 7s - 17ms/step - accuracy: 0.4510 - loss: 1.5448 - val_accuracy: 0.4479 - val_loss: 1.5406
# Epoch 4/50
# 391/391 - 7s - 17ms/step - accuracy: 0.4764 - loss: 1.4822 - val_accuracy: 0.4490 - val_loss: 1.5397
# Epoch 5/50
# 391/391 - 7s - 17ms/step - accuracy: 0.4917 - loss: 1.4325 - val_accuracy: 0.4770 - val_loss: 1.4705
# Epoch 6/50
# 391/391 - 7s - 17ms/step - accuracy: 0.5100 - loss: 1.3843 - val_accuracy: 0.4985 - val_loss: 1.4195
# Epoch 7/50
# 391/391 - 7s - 17ms/step - accuracy: 0.5214 - loss: 1.3483 - val_accuracy: 0.4897 - val_loss: 1.4191
# Epoch 8/50
# 391/391 - 7s - 17ms/step - accuracy: 0.5352 - loss: 1.3123 - val_accuracy: 0.5067 - val_loss: 1.3861
# Epoch 9/50
# 391/391 - 7s - 17ms/step - accuracy: 0.5505 - loss: 1.2805 - val_accuracy: 0.5086 - val_loss: 1.3802
# Epoch 10/50
# 391/391 - 7s - 18ms/step - accuracy: 0.5628 - loss: 1.2429 - val_accuracy: 0.5302 - val_loss: 1.3274
# Epoch 11/50
# 391/391 - 7s - 17ms/step - accuracy: 0.5720 - loss: 1.2143 - val_accuracy: 0.5250 - val_loss: 1.3338
# Epoch 12/50
# 391/391 - 7s - 17ms/step - accuracy: 0.5846 - loss: 1.1814 - val_accuracy: 0.5257 - val_loss: 1.3285
# Epoch 13/50
# 391/391 - 7s - 18ms/step - accuracy: 0.5946 - loss: 1.1541 - val_accuracy: 0.5288 - val_loss: 1.3435
# Epoch 14/50
# 391/391 - 7s - 18ms/step - accuracy: 0.6063 - loss: 1.1205 - val_accuracy: 0.5341 - val_loss: 1.3288
# Epoch 15/50
# 391/391 - 7s - 18ms/step - accuracy: 0.6140 - loss: 1.0992 - val_accuracy: 0.5369 - val_loss: 1.3106
# Epoch 16/50
# 391/391 - 7s - 17ms/step - accuracy: 0.6255 - loss: 1.0690 - val_accuracy: 0.5374 - val_loss: 1.3120
# Epoch 17/50
# 391/391 - 7s - 17ms/step - accuracy: 0.6401 - loss: 1.0303 - val_accuracy: 0.5408 - val_loss: 1.3203
# Epoch 18/50
# 391/391 - 7s - 17ms/step - accuracy: 0.6486 - loss: 1.0076 - val_accuracy: 0.5296 - val_loss: 1.3539
# Epoch 19/50
# 391/391 - 7s - 17ms/step - accuracy: 0.6561 - loss: 0.9822 - val_accuracy: 0.5468 - val_loss: 1.3013
# Epoch 20/50
# 391/391 - 7s - 19ms/step - accuracy: 0.6673 - loss: 0.9537 - val_accuracy: 0.5403 - val_loss: 1.3194
# Epoch 21/50
# 391/391 - 7s - 19ms/step - accuracy: 0.6754 - loss: 0.9304 - val_accuracy: 0.5444 - val_loss: 1.3157
# Epoch 22/50
# 391/391 - 8s - 20ms/step - accuracy: 0.6878 - loss: 0.8950 - val_accuracy: 0.5466 - val_loss: 1.3335
# Epoch 23/50
# 391/391 - 7s - 18ms/step - accuracy: 0.6966 - loss: 0.8716 - val_accuracy: 0.5307 - val_loss: 1.3949
# Epoch 24/50
# 391/391 - 7s - 18ms/step - accuracy: 0.7010 - loss: 0.8573 - val_accuracy: 0.5487 - val_loss: 1.3394
# Epoch 25/50
# 391/391 - 7s - 19ms/step - accuracy: 0.7179 - loss: 0.8160 - val_accuracy: 0.5421 - val_loss: 1.3563
# Epoch 26/50
# 391/391 - 7s - 19ms/step - accuracy: 0.7238 - loss: 0.7948 - val_accuracy: 0.5416 - val_loss: 1.3707
# Epoch 27/50
# 391/391 - 7s - 19ms/step - accuracy: 0.7334 - loss: 0.7698 - val_accuracy: 0.5564 - val_loss: 1.3419
# Epoch 28/50
# 391/391 - 8s - 20ms/step - accuracy: 0.7416 - loss: 0.7476 - val_accuracy: 0.5442 - val_loss: 1.4052
# Epoch 29/50
# 391/391 - 7s - 19ms/step - accuracy: 0.7514 - loss: 0.7175 - val_accuracy: 0.5518 - val_loss: 1.3501
# Epoch 30/50
# 391/391 - 8s - 19ms/step - accuracy: 0.7580 - loss: 0.6948 - val_accuracy: 0.5533 - val_loss: 1.3730
# Epoch 31/50
# 391/391 - 8s - 19ms/step - accuracy: 0.7707 - loss: 0.6695 - val_accuracy: 0.5555 - val_loss: 1.3935
# Epoch 32/50
# 391/391 - 7s - 19ms/step - accuracy: 0.7771 - loss: 0.6483 - val_accuracy: 0.5540 - val_loss: 1.4162
# Epoch 33/50
# 391/391 - 7s - 19ms/step - accuracy: 0.7849 - loss: 0.6237 - val_accuracy: 0.5486 - val_loss: 1.4386
# Epoch 34/50
# 391/391 - 8s - 19ms/step - accuracy: 0.7958 - loss: 0.6006 - val_accuracy: 0.5531 - val_loss: 1.4519
# Epoch 35/50
# 391/391 - 7s - 19ms/step - accuracy: 0.8030 - loss: 0.5795 - val_accuracy: 0.5529 - val_loss: 1.4546
# Epoch 36/50
# 391/391 - 8s - 20ms/step - accuracy: 0.8087 - loss: 0.5586 - val_accuracy: 0.5506 - val_loss: 1.5001
# Epoch 37/50
# 391/391 - 8s - 19ms/step - accuracy: 0.8178 - loss: 0.5362 - val_accuracy: 0.5515 - val_loss: 1.4723
# Epoch 38/50
# 391/391 - 7s - 19ms/step - accuracy: 0.8277 - loss: 0.5115 - val_accuracy: 0.5493 - val_loss: 1.5429
# Epoch 39/50
# 391/391 - 8s - 20ms/step - accuracy: 0.8352 - loss: 0.4893 - val_accuracy: 0.5440 - val_loss: 1.6073
# Epoch 40/50
# 391/391 - 8s - 19ms/step - accuracy: 0.8404 - loss: 0.4722 - val_accuracy: 0.5544 - val_loss: 1.5421
# Epoch 41/50
# 391/391 - 8s - 20ms/step - accuracy: 0.8491 - loss: 0.4509 - val_accuracy: 0.5513 - val_loss: 1.5898
# Epoch 42/50
# 391/391 - 8s - 20ms/step - accuracy: 0.8550 - loss: 0.4338 - val_accuracy: 0.5573 - val_loss: 1.6002
# Epoch 43/50
# 391/391 - 8s - 20ms/step - accuracy: 0.8611 - loss: 0.4177 - val_accuracy: 0.5534 - val_loss: 1.6433
# Epoch 44/50
# 391/391 - 8s - 19ms/step - accuracy: 0.8679 - loss: 0.3991 - val_accuracy: 0.5433 - val_loss: 1.7339
# Epoch 45/50
# 391/391 - 7s - 19ms/step - accuracy: 0.8764 - loss: 0.3771 - val_accuracy: 0.5581 - val_loss: 1.6824
# Epoch 46/50
# 391/391 - 7s - 19ms/step - accuracy: 0.8824 - loss: 0.3583 - val_accuracy: 0.5542 - val_loss: 1.6767
# Epoch 47/50
# 391/391 - 8s - 19ms/step - accuracy: 0.8864 - loss: 0.3466 - val_accuracy: 0.5494 - val_loss: 1.7379
# Epoch 48/50
# 391/391 - 7s - 19ms/step - accuracy: 0.8906 - loss: 0.3351 - val_accuracy: 0.5404 - val_loss: 1.7839
# Epoch 49/50
# 391/391 - 7s - 19ms/step - accuracy: 0.8946 - loss: 0.3212 - val_accuracy: 0.5463 - val_loss: 1.8038
# Epoch 50/50
# 391/391 - 8s - 20ms/step - accuracy: 0.9004 - loss: 0.3046 - val_accuracy: 0.5508 - val_loss: 1.8341

# %%
res_adam = mlp_adam.evaluate(x_test, y_test, verbose=0)
print('accuracy =', res_adam[1] * 100, '%')
# Out:
# accuracy = 55.080002546310425 %

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['train', 'test'])
plt.grid()
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'test'])
plt.grid()
plt.show()
