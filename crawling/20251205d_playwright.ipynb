# %% [markdown]
# # playwright
# - selenium 보다 많이 사용
# - webdriver 설치 및 경로 관리가 없음 (최신 브라우저와 연동되는 브라우저 드라이버를 자동으로 다운로드하고 관리)
# - 프레임, 팝업, 다운로드, 업로드등 API가 일관되고 깔끔
# - 병렬 실행, 트레이싱, 네트워크 인터셉트(요청/응답 가로채기) 쉬움

# %%
# Jupyter Notebook 설정 : 모든 결과 출력
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
# !pip install playwright

# %% [markdown]
# ## example

# %%
from playwright.sync_api import sync_playwright

url = "https://example.com/products"
with sync_playwright() as p:
    browser = p.chromium.launch(headless=False)
    page = browser.new_page()
    page.goto(url, wait_until="networkidle")
    if (page.is_visible("button.load-more")):
        page.click("button.load-more")
        page.wait_for_selector(".card")
    names = [e.inner_text() for e in page.query_selector_all(".card .name")]
    print(names)
    browser.close()

# %% [markdown]
# # END
